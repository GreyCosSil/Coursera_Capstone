# %% [markdown]
# # Challenge: which neighborhood of Dublin Should i open my bar?

# %% [markdown]
# In ireland there are too many bars around dublin, because of being an exciting night city, I think that open a bar there is a great business because the most part of irish people like to go to the bar to watching games on TV or met some friends, maybe dancing, what is really fun, they really know how to have fun, in addition, every year the city receives many foreigners.

# %% [markdown]
# first at all some neighborhood are being chosen to exploration of the area, will be token a 5km from the choosed point.

# %% [markdown]
# The first exploration city will be in the address St. James's Gate, Dublin 8, Irland, i'll look to see where there are the most part of bars and try to find the best one for me, that is: where there are less bars.

# %% [markdown]
# # 1. Importing some package:

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

from pandas.io.json import json_normalize

import folium # plotting library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # 2. Defining some data:

# %%
CLIENT_ID = '2ECMKGACQRNDAOTLP02N52AXE5A0AUCMK5RBWF5TWHSBLI41' # your Foursquare ID
CLIENT_SECRET = 'CGYL4DFESDX1MSNLQBTPV2WAFV4FABLQ5WZS2IODNVQ0LDAX' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 1000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2ECMKGACQRNDAOTLP02N52AXE5A0AUCMK5RBWF5TWHSBLI41
# CLIENT_SECRET:CGYL4DFESDX1MSNLQBTPV2WAFV4FABLQ5WZS2IODNVQ0LDAX

# %% [markdown]
# # 3. Looking around St. James's Gate in a 10KM radius

# %%
address = "St. James's Gate, Dublin 8, Irland"

geolocator = Nominatim(user_agent="dublin_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 53.34335525 -6.296271153198848

# %%
radius = 10000
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=2ECMKGACQRNDAOTLP02N52AXE5A0AUCMK5RBWF5TWHSBLI41&client_secret=CGYL4DFESDX1MSNLQBTPV2WAFV4FABLQ5WZS2IODNVQ0LDAX&ll=53.34335525,-6.296271153198848&v=20180604&radius=10000&limit=1000'

# %% [markdown]
# # 4. Taking the result and putting on a JSON file

# %%
results = requests.get(url).json()
'There are {} around Guinness Storehouse.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 100 around Guinness Storehouse.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '504f4190e4b0a4306af36384',
#   'name': 'Phoenix Park, Park Gate St. Entrance',
#   'location': {'address': 'Park Gate St',
#    'lat': 53.35021920457069,
#    'lng': -6.300200292405377,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 53.35021920457069,
#      'lng': -6.300200292405377}],
#    'distance': 807,
#    'cc': 'IE',
#    'city': 'Dublin',
#    'state': 'Dublin City',
#    'country': 'Ireland',
#    'formattedAddress': ['Park Gate St', 'Dublin', 'Dublin City', 'Ireland']},
#   'categories': [{'id': '4deefb944765f83613cdba6e',
#     'name': 'Historic Site',
#     'pluralName': 'Historic Sites',
#     'shortName': 'Historic Site',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-504f4190e4b0a4306af36384-0'}

# %%
dataIreland = json_normalize(items) # flatten JSON
# Out:
# /home/greyce/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.

# %%
dataIreland.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-504f4190e4b0a4306af36384-0              0
# 1  e-0-4ade0f54f964a520fd7121e3-1              0
# 2  e-0-510025fee4b0ef659f880506-2              0
# 3  e-0-4e11ee72ae602afe96c11aa6-3              0
# 4  e-0-4ba92deef964a52013123ae3-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id                            venue.name  \
# 0  504f4190e4b0a4306af36384  Phoenix Park, Park Gate St. Entrance
# 1  4ade0f54f964a520fd7121e3         The Royal Hospital Kilmainham
# 2  510025fee4b0ef659f880506                            PHX Bistro
# 3  4e11ee72ae602afe96c11aa6   Irish National War Memorial Gardens
# 4  4ba92deef964a52013123ae3                   Guinness Storehouse
#
#                               venue.location.address  venue.location.lat  \
# 0                                       Park Gate St           53.350219
# 1                                        Military Rd           53.343238
# 2                                      12 Ellis Quay           53.346592
# 3  Gairdíní Náisiúnta Cuimhneacháin Cogaidh na hÉ...           53.343898
# 4                                    St James's Gate           53.341890
#
#    venue.location.lng                      venue.location.labeledLatLngs  \
# 0           -6.300200  [{'label': 'display', 'lat': 53.35021920457069...
# 1           -6.300118  [{'label': 'display', 'lat': 53.34323842742987...
# 2           -6.281092  [{'label': 'display', 'lat': 53.34659185284413...
# 3           -6.315810  [{'label': 'display', 'lat': 53.34389785898711...
# 4           -6.286734  [{'label': 'display', 'lat': 53.3418895355902,...
#
#    venue.location.distance  ... venue.location.state venue.location.country  \
# 0                      807  ...          Dublin City                Ireland
# 1                      256  ...          Dublin City                Ireland
# 2                     1071  ...          Dublin City                Ireland
# 3                     1299  ...          Dublin City                Ireland
# 4                      654  ...          Dublin City                Ireland
#
#                      venue.location.formattedAddress  \
# 0       [Park Gate St, Dublin, Dublin City, Ireland]
# 1        [Military Rd, Dublin, Dublin City, Ireland]
# 2      [12 Ellis Quay, Dublin, Dublin City, Ireland]
# 3  [Gairdíní Náisiúnta Cuimhneacháin Cogaidh na h...
# 4    [St James's Gate, Dublin, Dublin City, Ireland]
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4deefb944765f83613cdba6e', 'name': 'H...                  0
# 1  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...                  0
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...                  0
# 3  [{'id': '4bf58dd8d48988d15a941735', 'name': 'G...                  0
# 4  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...                  0
#
#   venue.photos.groups  venue.location.postalCode venue.location.neighborhood  \
# 0                  []                        NaN                         NaN
# 1                  []                          8                         NaN
# 2                  []                          7                         NaN
# 3                  []                          8                         NaN
# 4                  []                          8                         NaN
#
#   venue.venuePage.id venue.location.crossStreet
# 0                NaN                        NaN
# 1                NaN                        NaN
# 2                NaN                        NaN
# 3                NaN                        NaN
# 4                NaN                        NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# # 5. Filtering some columns and cleaning then

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataIreland.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataIreland.loc[:, filtered_columns]


def get_category_name(row):
    try:
        categories_list = row['venue.categories']
    except:
        categories_list = row['venue.name']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

def get_category_id(row):
    try:
        categories_list = row['venue.categories']
    except:
        categories_list = row['venue.name']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['id']
    
# filter the category for each row
dataframe_filtered['id_type'] = dataframe_filtered.apply(get_category_id, axis=1)
dataframe_filtered['name_type'] = dataframe_filtered.apply(get_category_name, axis=1)
    
# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]
    
# filter the category for each row

dataframe_filtered.head(10)
# Out:
#                                    name  \
# 0  Phoenix Park, Park Gate St. Entrance
# 1         The Royal Hospital Kilmainham
# 2                            PHX Bistro
# 3   Irish National War Memorial Gardens
# 4                   Guinness Storehouse
# 5                    Light House Cinema
# 6                           Gravity Bar
# 7                            Dublin Zoo
# 8        Phoenix Park Islandbridge Gate
# 9                     St Patrick's Park
#
#                                           categories  \
# 0  [{'id': '4deefb944765f83613cdba6e', 'name': 'H...
# 1  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
# 3  [{'id': '4bf58dd8d48988d15a941735', 'name': 'G...
# 4  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...
# 5  [{'id': '4bf58dd8d48988d17e941735', 'name': 'I...
# 6  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...
# 7  [{'id': '4bf58dd8d48988d17b941735', 'name': 'Z...
# 8  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 9  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
#
#                                              address        lat       lng  \
# 0                                       Park Gate St  53.350219 -6.300200
# 1                                        Military Rd  53.343238 -6.300118
# 2                                      12 Ellis Quay  53.346592 -6.281092
# 3  Gairdíní Náisiúnta Cuimhneacháin Cogaidh na hÉ...  53.343898 -6.315810
# 4                                    St James's Gate  53.341890 -6.286734
# 5                              Market Sq, Smithfield  53.348691 -6.278976
# 6                                    St James's Gate  53.341801 -6.286831
# 7                                       Phoenix Park  53.354280 -6.305311
# 8                                                NaN  53.348388 -6.307887
# 9                                         Patrick St  53.340110 -6.271894
#
#                                       labeledLatLngs  distance  cc    city  \
# 0  [{'label': 'display', 'lat': 53.35021920457069...       807  IE  Dublin
# 1  [{'label': 'display', 'lat': 53.34323842742987...       256  IE  Dublin
# 2  [{'label': 'display', 'lat': 53.34659185284413...      1071  IE  Dublin
# 3  [{'label': 'display', 'lat': 53.34389785898711...      1299  IE  Dublin
# 4  [{'label': 'display', 'lat': 53.3418895355902,...       654  IE  Dublin
# 5  [{'label': 'display', 'lat': 53.34869068064911...      1293  IE  Dublin
# 6  [{'label': 'display', 'lat': 53.3418007487522,...       650  IE  Dublin
# 7  [{'label': 'display', 'lat': 53.35428046548301...      1356  IE  Dublin
# 8  [{'label': 'display', 'lat': 53.34838806784713...       953  IE  Dublin
# 9  [{'label': 'display', 'lat': 53.34011037061703...      1659  IE  Dublin
#
#          state  country                                   formattedAddress  \
# 0  Dublin City  Ireland       [Park Gate St, Dublin, Dublin City, Ireland]
# 1  Dublin City  Ireland        [Military Rd, Dublin, Dublin City, Ireland]
# 2  Dublin City  Ireland      [12 Ellis Quay, Dublin, Dublin City, Ireland]
# 3  Dublin City  Ireland  [Gairdíní Náisiúnta Cuimhneacháin Cogaidh na h...
# 4  Dublin City  Ireland    [St James's Gate, Dublin, Dublin City, Ireland]
# 5  Dublin City  Ireland  [Market Sq, Smithfield, Dublin, Dublin City, I...
# 6  Dublin City  Ireland    [St James's Gate, Dublin, Dublin City, Ireland]
# 7  Dublin City  Ireland       [Phoenix Park, Dublin, Dublin City, Ireland]
# 8  Dublin City  Ireland                     [Dublin, Dublin City, Ireland]
# 9  Dublin City  Ireland         [Patrick St, Dublin, Dublin City, Ireland]
#
#   postalCode neighborhood crossStreet                        id  \
# 0        NaN          NaN         NaN  504f4190e4b0a4306af36384
# 1          8          NaN         NaN  4ade0f54f964a520fd7121e3
# 2          7          NaN         NaN  510025fee4b0ef659f880506
# 3          8          NaN         NaN  4e11ee72ae602afe96c11aa6
# 4          8          NaN         NaN  4ba92deef964a52013123ae3
# 5          7          NaN         NaN  4b081db2f964a5201a0423e3
# 6          8          NaN         NaN  4ba3a0b7f964a5208c4d38e3
# 7          8          NaN         NaN  4b3764cdf964a520d74025e3
# 8          8          NaN         NaN  4fbbc32fe4b0d1b2bf9ef20b
# 9          8          NaN         NaN  4bc1e1cc2a89ef3b2cd1f288
#
#                     id_type            name_type
# 0  4deefb944765f83613cdba6e        Historic Site
# 1  4bf58dd8d48988d1e2931735          Art Gallery
# 2  4bf58dd8d48988d1c4941735           Restaurant
# 3  4bf58dd8d48988d15a941735               Garden
# 4  50327c8591d4c4b30a586d5d              Brewery
# 5  4bf58dd8d48988d17e941735  Indie Movie Theater
# 6  4bf58dd8d48988d116941735                  Bar
# 7  4bf58dd8d48988d17b941735                  Zoo
# 8  4bf58dd8d48988d163941735                 Park
# 9  4bf58dd8d48988d163941735                 Park

# %% [markdown]
# # 6. Transforming the JSON file into a DataFrame

# %%
dataframe_filtered=pd.DataFrame(dataframe_filtered)

# %% [markdown]
# # 7. Plotting the data in a Map

# %%
dublin_map = folium.Map(location=[latitude, longitude], zoom_start=12) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='Green',
    fill_color='Green',
    fill_opacity=0.6
    ).add_to(dublin_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['categories']):
    label = '{}, {}'.format(dataframe_filtered['name_type'], dataframe_filtered['distance'])
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(dublin_map) 

# display map
dublin_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 8. Searching for Bars in the same address

# %%
search_query = 'Bar'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Bar .... OK!

# %%
url1 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url1
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2ECMKGACQRNDAOTLP02N52AXE5A0AUCMK5RBWF5TWHSBLI41&client_secret=CGYL4DFESDX1MSNLQBTPV2WAFV4FABLQ5WZS2IODNVQ0LDAX&ll=53.34335525,-6.296271153198848&v=20180604&query=Bar&radius=1000&limit=1000'

# %%
result1 = requests.get(url1).json()
result1
# Out:
# {'meta': {'code': 200, 'requestId': '5f149addbc542b0b9ad86ffd'},
#  'response': {'venues': [{'id': '4ba3a0b7f964a5208c4d38e3',
#     'name': 'Gravity Bar',
#     'location': {'address': "St James's Gate",
#      'lat': 53.3418007487522,
#      'lng': -6.2868310203070905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.3418007487522,
#        'lng': -6.2868310203070905}],
#      'distance': 650,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ["St James's Gate",
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4bbe0eb2c6a2ef3be336ddbd',
#     'name': 'Zumo Natural Smoothie Bar',
#     'location': {'address': 'Heuston Station',
#      'lat': 53.34649103635387,
#      'lng': -6.292730761737872,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34649103635387,
#        'lng': -6.292730761737872}],
#      'distance': 420,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Heuston Station',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d112941735',
#       'name': 'Juice Bar',
#       'pluralName': 'Juice Bars',
#       'shortName': 'Juice Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '50899302e4b0ddcb6cfa89ff',
#     'name': 'Connoisseur Bar',
#     'location': {'address': "St James's Gate",
#      'lat': 53.34185838384853,
#      'lng': -6.286738377836775,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34185838384853,
#        'lng': -6.286738377836775}],
#      'distance': 655,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ["St James's Gate",
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4fe4e0f6e4b08674c9cb2716',
#     'name': "Arthur's Bar",
#     'location': {'address': "St James's Gate",
#      'lat': 53.34180784712872,
#      'lng': -6.2866634130477905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34180784712872,
#        'lng': -6.2866634130477905}],
#      'distance': 661,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ["St James's Gate",
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '50ca02c2245f2d4aa8c2ba6b',
#     'name': '4 Corners Bar And Terrace',
#     'location': {'address': 'Hilton Dublin Kilmainham',
#      'crossStreet': 'Inchicore Rd',
#      'lat': 53.342869128036135,
#      'lng': -6.309078427977643,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.342869128036135,
#        'lng': -6.309078427977643}],
#      'distance': 852,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Hilton Dublin Kilmainham (Inchicore Rd)',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4b05afdcf964a520f8e022e3',
#     'name': 'Pifko Bar',
#     'location': {'address': '41-43 Ushers Quay',
#      'lat': 53.345964,
#      'lng': -6.28031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.345964,
#        'lng': -6.28031}],
#      'distance': 1099,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['41-43 Ushers Quay',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4bab3531f964a52083993ae3',
#     'name': "O'Brien's Sandwich Bar",
#     'location': {'lat': 53.342797,
#      'lng': -6.278284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.342797,
#        'lng': -6.278284}],
#      'distance': 1197,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '5171c0c9e4b04c634eb476e8',
#     'name': 'Hibiscus Wilde Vegan Food Bar',
#     'location': {'address': '72 Thomas St',
#      'lat': 53.34258621323808,
#      'lng': -6.276483145898667,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34258621323808,
#        'lng': -6.276483145898667}],
#      'distance': 1317,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['72 Thomas St', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '51450c55e4b0df0d72b2ccc9',
#     'name': 'Harkins Bar',
#     'location': {'lat': 53.34243135098475,
#      'lng': -6.288203188566733,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34243135098475,
#        'lng': -6.288203188566733}],
#      'distance': 545,
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4af4a6cbf964a520b2f421e3',
#     'name': "Frank Ryan's Bar",
#     'location': {'address': '5 Queen St',
#      'lat': 53.34697801477413,
#      'lng': -6.280061252290714,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34697801477413,
#        'lng': -6.280061252290714}],
#      'distance': 1150,
#      'postalCode': '7',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['5 Queen St', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4d502c614015b1f7c1ac63cf',
#     'name': 'Bakers Bar',
#     'location': {'address': '92-95 Meath St',
#      'crossStreet': '47-48 Thomas St',
#      'lat': 53.34279796980291,
#      'lng': -6.278916778117533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34279796980291,
#        'lng': -6.278916778117533}],
#      'distance': 1155,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['92-95 Meath St (47-48 Thomas St)',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '530e8e9b498e8e842d1c3b7f',
#     'name': 'brewery bar newport st',
#     'location': {'lat': 53.340541,
#      'lng': -6.287024,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.340541,
#        'lng': -6.287024}],
#      'distance': 689,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4cf69320e308236a29f7e6ac',
#     'name': "McCauley's Bar & Lounge",
#     'location': {'lat': 53.3360481262207,
#      'lng': -6.2980518,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.3360481262207,
#        'lng': -6.2980518}],
#      'distance': 821,
#      'cc': 'IE',
#      'city': 'Rialto',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Rialto', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '5d6bdeab2c61ca0008aa38d5',
#     'name': 'Power House Bar',
#     'location': {'address': '92 James’s Street',
#      'lat': 53.343994,
#      'lng': -6.285864,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.343994,
#        'lng': -6.285864}],
#      'distance': 695,
#      'postalCode': 'DUBLIN 8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'country': 'Ireland',
#      'formattedAddress': ['92 James’s Street', 'Dublin', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '58c31a706ad73d0d9980ba1b',
#     'name': 'Broyage Bar & Bistro',
#     'location': {'address': 'Hilton Kilmainham, S Circular Rd',
#      'lat': 53.342285,
#      'lng': -6.3084173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.342285,
#        'lng': -6.3084173}],
#      'distance': 815,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'country': 'Ireland',
#      'formattedAddress': ['Hilton Kilmainham, S Circular Rd',
#       'Dublin',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '5058da13e4b0a3bd5566fd12',
#     'name': 'Iveagh Bar',
#     'location': {'address': 'Parkgate Street',
#      'lat': 53.347844412717855,
#      'lng': -6.290874760847697,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.347844412717855,
#        'lng': -6.290874760847697}],
#      'distance': 615,
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Parkgate Street',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '57daef8ecd104981a7e6394e',
#     'name': 'The Mission Bar',
#     'location': {'address': '30 Ellis Quay',
#      'lat': 53.34709,
#      'lng': -6.283828,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34709,
#        'lng': -6.283828}],
#      'distance': 925,
#      'postalCode': '7',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['30 Ellis Quay',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d118941735',
#       'name': 'Dive Bar',
#       'pluralName': 'Dive Bars',
#       'shortName': 'Dive Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '56f3f7a5498ea87d6d8d2850',
#     'name': '1837 Bar & Brasserie',
#     'location': {'address': "St James's Gate",
#      'lat': 53.34183747275798,
#      'lng': -6.286647319793701,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34183747275798,
#        'lng': -6.286647319793701}],
#      'distance': 661,
#      'postalCode': '8',
#      'cc': 'IE',
#      'neighborhood': 'Dublin City',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ["St James's Gate",
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '51ec042d498e00bc1d40f2f5',
#     'name': "Big's Bar",
#     'location': {'lat': 53.34698479246681,
#      'lng': -6.281621506888761,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34698479246681,
#        'lng': -6.281621506888761}],
#      'distance': 1054,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '52876ce211d2f357d91145f9',
#     'name': "O'Rourkes Deli Bar",
#     'location': {'address': 'Bridgefoot St',
#      'lat': 53.34578180790874,
#      'lng': -6.280787661142743,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34578180790874,
#        'lng': -6.280787661142743}],
#      'distance': 1063,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Bridgefoot St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4ce589dedfaef04d39a56e83',
#     'name': "God's Bar",
#     'location': {'address': 'Vicar street',
#      'lat': 53.342953,
#      'lng': -6.2770242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.342953,
#        'lng': -6.2770242}],
#      'distance': 1279,
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Vicar street', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '517171a6e4b0978a47f4ca8a',
#     'name': "Oscar Verne's Coffee Bar",
#     'location': {'address': '72 Thomas Street @ The Ferocious Mingle Marcade',
#      'lat': 53.34326094706608,
#      'lng': -6.276616103598986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34326094706608,
#        'lng': -6.276616103598986}],
#      'distance': 1306,
#      'cc': 'IE',
#      'city': 'Dublin 8',
#      'country': 'Ireland',
#      'formattedAddress': ['72 Thomas Street @ The Ferocious Mingle Marcade',
#       'Dublin 8',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '50509ff8e4b0473d5f54cd7b',
#     'name': 'Barge Café',
#     'location': {'address': "St James's Gate",
#      'lat': 53.341760222490514,
#      'lng': -6.286899001567008,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.341760222490514,
#        'lng': -6.286899001567008}],
#      'distance': 647,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ["St James's Gate",
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '52873bbf11d248c7de2a4c77',
#     'name': 'The Barley House',
#     'location': {'address': 'Dublin',
#      'crossStreet': 'Cork Street',
#      'lat': 53.337415,
#      'lng': -6.289274,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.337415,
#        'lng': -6.289274}],
#      'distance': 808,
#      'postalCode': 'Dublin 8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Dublin (Cork Street)',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '5032891291d4c4b30a586d68',
#       'name': 'Assisted Living',
#       'pluralName': 'Assisted Living',
#       'shortName': 'Assisted Living',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '511676dee4b0ec5107171946',
#     'name': 'The Barley House',
#     'location': {'address': 'Marrowbone Ln',
#      'lat': 53.33752612796867,
#      'lng': -6.2868860887182825,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33752612796867,
#        'lng': -6.2868860887182825}],
#      'distance': 900,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Marrowbone Ln',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '5041eb01e4b0591b22da6a45',
#     'name': 'Bargaintown',
#     'location': {'address': 'Queen St',
#      'lat': 53.34686543456666,
#      'lng': -6.279999772927651,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34686543456666,
#        'lng': -6.279999772927651}],
#      'distance': 1149,
#      'postalCode': '7',
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Queen St', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '517284bfe4b0745535058072',
#     'name': 'The Bardic Bookstall',
#     'location': {'address': '72 Thomas St.',
#      'lat': 53.342645489531506,
#      'lng': -6.27646243024003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.342645489531506,
#        'lng': -6.27646243024003}],
#      'distance': 1318,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['72 Thomas St.',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'shortName': 'Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '5502eece498edcf46c4fe813',
#     'name': 'J&R Bros Barber Shop',
#     'location': {'address': 'Reuben St',
#      'crossStreet': 'Fatima',
#      'lat': 53.338549097270516,
#      'lng': -6.291951021731292,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.338549097270516,
#        'lng': -6.291951021731292}],
#      'distance': 607,
#      'postalCode': 'D8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Reuben St (Fatima)',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4f3f7994e4b0f13aa602cb7e',
#     'name': "Martin's Barber Shop",
#     'location': {'address': 'Conyngham Rd, Dublin 8',
#      'lat': 53.34804676994135,
#      'lng': -6.294604970710568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34804676994135,
#        'lng': -6.294604970710568}],
#      'distance': 533,
#      'postalCode': 'Dublin 8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Conyngham Rd, Dublin 8',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '510bb81ce4b077915ef76d03',
#     'name': 'Parkgate Barbers',
#     'location': {'lat': 53.348036,
#      'lng': -6.293153,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.348036,
#        'lng': -6.293153}],
#      'distance': 560,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '5409b101498eaf564c42fff6',
#     'name': "Ray's Barber",
#     'location': {'lat': 53.3411502859721,
#      'lng': -6.2816355343556385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.3411502859721,
#        'lng': -6.2816355343556385}],
#      'distance': 1003,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4af9f82af964a520a71522e3',
#     'name': "Dolphin's Barn / An Carnán",
#     'location': {'lat': 53.33866285919825,
#      'lng': -6.289878309062108,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33866285919825,
#        'lng': -6.289878309062108}],
#      'distance': 673,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4f2a25ac4b909258e854f55f',
#       'name': 'Neighborhood',
#       'pluralName': 'Neighborhoods',
#       'shortName': 'Neighborhood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '5ae338e9acb00b002c44021d',
#     'name': 'New Look Barber Shop',
#     'location': {'address': 'Cork Street',
#      'lat': 53.33683,
#      'lng': -6.287664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33683,
#        'lng': -6.287664}],
#      'distance': 924,
#      'postalCode': 'DUBLIN 8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'country': 'Ireland',
#      'formattedAddress': ['Cork Street', 'Dublin', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4d32fc065c2db60ce220c76c',
#     'name': "Clifford's Barber",
#     'location': {'lat': 53.33650556079923,
#      'lng': -6.287639827343725,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33650556079923,
#        'lng': -6.287639827343725}],
#      'distance': 954,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d10c951735',
#       'name': 'Cosmetics Shop',
#       'pluralName': 'Cosmetics Shops',
#       'shortName': 'Cosmetics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '58e78b740acb6a688a378733',
#     'name': 'Alfa Bargains',
#     'location': {'address': '42-45 Thomas St',
#      'lat': 53.34282,
#      'lng': -6.279386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34282,
#        'lng': -6.279386}],
#      'distance': 1123,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'country': 'Ireland',
#      'formattedAddress': ['42-45 Thomas St', 'Dublin', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d112951735',
#       'name': 'Hardware Store',
#       'pluralName': 'Hardware Stores',
#       'shortName': 'Hardware',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4d82472f5b942c0ff6f7a5f1',
#     'name': 'Thomas Barber Shop',
#     'location': {'address': 'Thomas Street',
#      'lat': 53.34299904945636,
#      'lng': -6.278448519585081,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34299904945636,
#        'lng': -6.278448519585081}],
#      'distance': 1185,
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Thomas Street',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4e1878e62271b0e971fc30aa',
#     'name': 'The Mad Barber',
#     'location': {'address': 'Cork Street, Emerald Sq',
#      'lat': 53.33449205263579,
#      'lng': -6.290001648714126,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33449205263579,
#        'lng': -6.290001648714126}],
#      'distance': 1071,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Cork Street, Emerald Sq',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '572c7fb7498edf83df0e9ed6',
#     'name': 'Claude Barbers',
#     'location': {'lat': 53.3426,
#      'lng': -6.279202,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.3426,
#        'lng': -6.279202}],
#      'distance': 1137,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False},
#    {'id': '4c87e7b318209521e1d2aeef',
#     'name': "Dolphin's Barn Scout Den",
#     'location': {'address': "Dolphin's Barn St",
#      'lat': 53.33375653657439,
#      'lng': -6.290118612752751,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33375653657439,
#        'lng': -6.290118612752751}],
#      'distance': 1144,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ["Dolphin's Barn St",
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e4941735',
#       'name': 'Campground',
#       'pluralName': 'Campgrounds',
#       'shortName': 'Campground',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/campground_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186424',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venuesBar = result1['response']['venues']

# tranform venues into a dataframe
dataBar = json_normalize(venuesBar)
dataBar.head()
# Out:
# /home/greyce/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                       name  \
# 0  4ba3a0b7f964a5208c4d38e3                Gravity Bar
# 1  4bbe0eb2c6a2ef3be336ddbd  Zumo Natural Smoothie Bar
# 2  50899302e4b0ddcb6cfa89ff            Connoisseur Bar
# 3  4fe4e0f6e4b08674c9cb2716               Arthur's Bar
# 4  50ca02c2245f2d4aa8c2ba6b  4 Corners Bar And Terrace
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1595186424    False
# 1  [{'id': '4bf58dd8d48988d112941735', 'name': 'J...  v-1595186424    False
# 2  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1595186424    False
# 3  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1595186424    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1595186424    False
#
#            location.address  location.lat  location.lng  \
# 0           St James's Gate     53.341801     -6.286831
# 1           Heuston Station     53.346491     -6.292731
# 2           St James's Gate     53.341858     -6.286738
# 3           St James's Gate     53.341808     -6.286663
# 4  Hilton Dublin Kilmainham     53.342869     -6.309078
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 53.3418007487522,...                650
# 1  [{'label': 'display', 'lat': 53.34649103635387...                420
# 2  [{'label': 'display', 'lat': 53.34185838384853...                655
# 3  [{'label': 'display', 'lat': 53.34180784712872...                661
# 4  [{'label': 'display', 'lat': 53.34286912803613...                852
#
#   location.postalCode location.cc location.city location.state  \
# 0                   8          IE        Dublin    Dublin City
# 1                   8          IE        Dublin    Dublin City
# 2                   8          IE        Dublin    Dublin City
# 3                   8          IE        Dublin    Dublin City
# 4                   8          IE        Dublin    Dublin City
#
#   location.country                          location.formattedAddress  \
# 0          Ireland    [St James's Gate, Dublin, Dublin City, Ireland]
# 1          Ireland    [Heuston Station, Dublin, Dublin City, Ireland]
# 2          Ireland    [St James's Gate, Dublin, Dublin City, Ireland]
# 3          Ireland    [St James's Gate, Dublin, Dublin City, Ireland]
# 4          Ireland  [Hilton Dublin Kilmainham (Inchicore Rd), Dubl...
#
#   location.crossStreet location.neighborhood
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4         Inchicore Rd                   NaN

# %%
dataBar.index
# Out:
# RangeIndex(start=0, stop=39, step=1)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataBar.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataBar.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                              name                                categories  \
# 0                     Gravity Bar                                       Bar
# 1       Zumo Natural Smoothie Bar                                 Juice Bar
# 2                 Connoisseur Bar                                       Bar
# 3                    Arthur's Bar                                       Pub
# 4       4 Corners Bar And Terrace                                Restaurant
# 5                       Pifko Bar                                       Pub
# 6          O'Brien's Sandwich Bar                            Sandwich Place
# 7   Hibiscus Wilde Vegan Food Bar             Vegetarian / Vegan Restaurant
# 8                     Harkins Bar                                       Bar
# 9                Frank Ryan's Bar                                       Pub
# 10                     Bakers Bar                                       Pub
# 11         brewery bar newport st                                       Pub
# 12        McCauley's Bar & Lounge                                       Bar
# 13                Power House Bar                              Cocktail Bar
# 14           Broyage Bar & Bistro                                 Hotel Bar
# 15                     Iveagh Bar                                 Hotel Bar
# 16                The Mission Bar                                  Dive Bar
# 17           1837 Bar & Brasserie                                Restaurant
# 18                      Big's Bar                                       Bar
# 19             O'Rourkes Deli Bar                            Breakfast Spot
# 20                      God's Bar                                      None
# 21       Oscar Verne's Coffee Bar                               Coffee Shop
# 22                     Barge Café                                      Café
# 23               The Barley House                           Assisted Living
# 24               The Barley House  Residential Building (Apartment / Condo)
# 25                    Bargaintown                    Furniture / Home Store
# 26           The Bardic Bookstall                                 Bookstore
# 27           J&R Bros Barber Shop                        Salon / Barbershop
# 28           Martin's Barber Shop                        Salon / Barbershop
# 29               Parkgate Barbers                        Salon / Barbershop
# 30                   Ray's Barber                        Salon / Barbershop
# 31     Dolphin's Barn / An Carnán                              Neighborhood
# 32           New Look Barber Shop                        Salon / Barbershop
# 33              Clifford's Barber                            Cosmetics Shop
# 34                  Alfa Bargains                            Hardware Store
# 35             Thomas Barber Shop                        Salon / Barbershop
# 36                 The Mad Barber                        Salon / Barbershop
# 37                 Claude Barbers                        Salon / Barbershop
# 38       Dolphin's Barn Scout Den                                Campground
#
#                                             address        lat       lng  \
# 0                                   St James's Gate  53.341801 -6.286831
# 1                                   Heuston Station  53.346491 -6.292731
# 2                                   St James's Gate  53.341858 -6.286738
# 3                                   St James's Gate  53.341808 -6.286663
# 4                          Hilton Dublin Kilmainham  53.342869 -6.309078
# 5                                 41-43 Ushers Quay  53.345964 -6.280310
# 6                                               NaN  53.342797 -6.278284
# 7                                      72 Thomas St  53.342586 -6.276483
# 8                                               NaN  53.342431 -6.288203
# 9                                        5 Queen St  53.346978 -6.280061
# 10                                   92-95 Meath St  53.342798 -6.278917
# 11                                              NaN  53.340541 -6.287024
# 12                                              NaN  53.336048 -6.298052
# 13                                92 James’s Street  53.343994 -6.285864
# 14                 Hilton Kilmainham, S Circular Rd  53.342285 -6.308417
# 15                                  Parkgate Street  53.347844 -6.290875
# 16                                    30 Ellis Quay  53.347090 -6.283828
# 17                                  St James's Gate  53.341837 -6.286647
# 18                                              NaN  53.346985 -6.281622
# 19                                    Bridgefoot St  53.345782 -6.280788
# 20                                     Vicar street  53.342953 -6.277024
# 21  72 Thomas Street @ The Ferocious Mingle Marcade  53.343261 -6.276616
# 22                                  St James's Gate  53.341760 -6.286899
# 23                                           Dublin  53.337415 -6.289274
# 24                                    Marrowbone Ln  53.337526 -6.286886
# 25                                         Queen St  53.346865 -6.280000
# 26                                    72 Thomas St.  53.342645 -6.276462
# 27                                        Reuben St  53.338549 -6.291951
# 28                           Conyngham Rd, Dublin 8  53.348047 -6.294605
# 29                                              NaN  53.348036 -6.293153
# 30                                              NaN  53.341150 -6.281636
# 31                                              NaN  53.338663 -6.289878
# 32                                      Cork Street  53.336830 -6.287664
# 33                                              NaN  53.336506 -6.287640
# 34                                  42-45 Thomas St  53.342820 -6.279386
# 35                                    Thomas Street  53.342999 -6.278449
# 36                          Cork Street, Emerald Sq  53.334492 -6.290002
# 37                                              NaN  53.342600 -6.279202
# 38                                Dolphin's Barn St  53.333757 -6.290119
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 53.3418007487522,...       650          8
# 1   [{'label': 'display', 'lat': 53.34649103635387...       420          8
# 2   [{'label': 'display', 'lat': 53.34185838384853...       655          8
# 3   [{'label': 'display', 'lat': 53.34180784712872...       661          8
# 4   [{'label': 'display', 'lat': 53.34286912803613...       852          8
# 5   [{'label': 'display', 'lat': 53.345964, 'lng':...      1099          8
# 6   [{'label': 'display', 'lat': 53.342797, 'lng':...      1197        NaN
# 7   [{'label': 'display', 'lat': 53.34258621323808...      1317          8
# 8   [{'label': 'display', 'lat': 53.34243135098475...       545        NaN
# 9   [{'label': 'display', 'lat': 53.34697801477413...      1150          7
# 10  [{'label': 'display', 'lat': 53.34279796980291...      1155          8
# 11  [{'label': 'display', 'lat': 53.340541, 'lng':...       689        NaN
# 12  [{'label': 'display', 'lat': 53.3360481262207,...       821        NaN
# 13  [{'label': 'display', 'lat': 53.343994, 'lng':...       695   DUBLIN 8
# 14  [{'label': 'display', 'lat': 53.342285, 'lng':...       815          8
# 15  [{'label': 'display', 'lat': 53.34784441271785...       615        NaN
# 16  [{'label': 'display', 'lat': 53.34709, 'lng': ...       925          7
# 17  [{'label': 'display', 'lat': 53.34183747275798...       661          8
# 18  [{'label': 'display', 'lat': 53.34698479246681...      1054        NaN
# 19  [{'label': 'display', 'lat': 53.34578180790874...      1063          2
# 20  [{'label': 'display', 'lat': 53.342953, 'lng':...      1279        NaN
# 21  [{'label': 'display', 'lat': 53.34326094706608...      1306        NaN
# 22  [{'label': 'display', 'lat': 53.34176022249051...       647          8
# 23  [{'label': 'display', 'lat': 53.337415, 'lng':...       808   Dublin 8
# 24  [{'label': 'display', 'lat': 53.33752612796867...       900          8
# 25  [{'label': 'display', 'lat': 53.34686543456666...      1149          7
# 26  [{'label': 'display', 'lat': 53.34264548953150...      1318          8
# 27  [{'label': 'display', 'lat': 53.33854909727051...       607         D8
# 28  [{'label': 'display', 'lat': 53.34804676994135...       533   Dublin 8
# 29  [{'label': 'display', 'lat': 53.348036, 'lng':...       560        NaN
# 30  [{'label': 'display', 'lat': 53.3411502859721,...      1003        NaN
# 31  [{'label': 'display', 'lat': 53.33866285919825...       673          8
# 32  [{'label': 'display', 'lat': 53.33683, 'lng': ...       924   DUBLIN 8
# 33  [{'label': 'display', 'lat': 53.33650556079923...       954        NaN
# 34  [{'label': 'display', 'lat': 53.34282, 'lng': ...      1123          8
# 35  [{'label': 'display', 'lat': 53.34299904945636...      1185        NaN
# 36  [{'label': 'display', 'lat': 53.33449205263579...      1071          8
# 37  [{'label': 'display', 'lat': 53.3426, 'lng': -...      1137        NaN
# 38  [{'label': 'display', 'lat': 53.33375653657439...      1144          8
#
#     cc      city        state  country  \
# 0   IE    Dublin  Dublin City  Ireland
# 1   IE    Dublin  Dublin City  Ireland
# 2   IE    Dublin  Dublin City  Ireland
# 3   IE    Dublin  Dublin City  Ireland
# 4   IE    Dublin  Dublin City  Ireland
# 5   IE    Dublin  Dublin City  Ireland
# 6   IE       NaN          NaN  Ireland
# 7   IE    Dublin  Dublin City  Ireland
# 8   IE    Dublin  Dublin City  Ireland
# 9   IE    Dublin  Dublin City  Ireland
# 10  IE    Dublin  Dublin City  Ireland
# 11  IE       NaN          NaN  Ireland
# 12  IE    Rialto  Dublin City  Ireland
# 13  IE    Dublin          NaN  Ireland
# 14  IE    Dublin          NaN  Ireland
# 15  IE    Dublin  Dublin City  Ireland
# 16  IE    Dublin  Dublin City  Ireland
# 17  IE    Dublin  Dublin City  Ireland
# 18  IE       NaN          NaN  Ireland
# 19  IE    Dublin  Dublin City  Ireland
# 20  IE    Dublin  Dublin City  Ireland
# 21  IE  Dublin 8          NaN  Ireland
# 22  IE    Dublin  Dublin City  Ireland
# 23  IE    Dublin  Dublin City  Ireland
# 24  IE    Dublin  Dublin City  Ireland
# 25  IE       NaN          NaN  Ireland
# 26  IE    Dublin  Dublin City  Ireland
# 27  IE    Dublin  Dublin City  Ireland
# 28  IE    Dublin  Dublin City  Ireland
# 29  IE       NaN          NaN  Ireland
# 30  IE       NaN          NaN  Ireland
# 31  IE    Dublin  Dublin City  Ireland
# 32  IE    Dublin          NaN  Ireland
# 33  IE       NaN          NaN  Ireland
# 34  IE    Dublin          NaN  Ireland
# 35  IE    Dublin  Dublin City  Ireland
# 36  IE    Dublin  Dublin City  Ireland
# 37  IE       NaN          NaN  Ireland
# 38  IE    Dublin  Dublin City  Ireland
#
#                                      formattedAddress      crossStreet  \
# 0     [St James's Gate, Dublin, Dublin City, Ireland]              NaN
# 1     [Heuston Station, Dublin, Dublin City, Ireland]              NaN
# 2     [St James's Gate, Dublin, Dublin City, Ireland]              NaN
# 3     [St James's Gate, Dublin, Dublin City, Ireland]              NaN
# 4   [Hilton Dublin Kilmainham (Inchicore Rd), Dubl...     Inchicore Rd
# 5   [41-43 Ushers Quay, Dublin, Dublin City, Ireland]              NaN
# 6                                           [Ireland]              NaN
# 7        [72 Thomas St, Dublin, Dublin City, Ireland]              NaN
# 8                      [Dublin, Dublin City, Ireland]              NaN
# 9          [5 Queen St, Dublin, Dublin City, Ireland]              NaN
# 10  [92-95 Meath St (47-48 Thomas St), Dublin, Dub...  47-48 Thomas St
# 11                                          [Ireland]              NaN
# 12                     [Rialto, Dublin City, Ireland]              NaN
# 13               [92 James’s Street, Dublin, Ireland]              NaN
# 14  [Hilton Kilmainham, S Circular Rd, Dublin, Ire...              NaN
# 15    [Parkgate Street, Dublin, Dublin City, Ireland]              NaN
# 16      [30 Ellis Quay, Dublin, Dublin City, Ireland]              NaN
# 17    [St James's Gate, Dublin, Dublin City, Ireland]              NaN
# 18                                          [Ireland]              NaN
# 19      [Bridgefoot St, Dublin, Dublin City, Ireland]              NaN
# 20       [Vicar street, Dublin, Dublin City, Ireland]              NaN
# 21  [72 Thomas Street @ The Ferocious Mingle Marca...              NaN
# 22    [St James's Gate, Dublin, Dublin City, Ireland]              NaN
# 23  [Dublin (Cork Street), Dublin, Dublin City, Ir...      Cork Street
# 24      [Marrowbone Ln, Dublin, Dublin City, Ireland]              NaN
# 25                                [Queen St, Ireland]              NaN
# 26      [72 Thomas St., Dublin, Dublin City, Ireland]              NaN
# 27  [Reuben St (Fatima), Dublin, Dublin City, Irel...           Fatima
# 28  [Conyngham Rd, Dublin 8, Dublin, Dublin City, ...              NaN
# 29                                          [Ireland]              NaN
# 30                                          [Ireland]              NaN
# 31                     [Dublin, Dublin City, Ireland]              NaN
# 32                     [Cork Street, Dublin, Ireland]              NaN
# 33                                          [Ireland]              NaN
# 34                 [42-45 Thomas St, Dublin, Ireland]              NaN
# 35      [Thomas Street, Dublin, Dublin City, Ireland]              NaN
# 36  [Cork Street, Emerald Sq, Dublin, Dublin City,...              NaN
# 37                                          [Ireland]              NaN
# 38  [Dolphin's Barn St, Dublin, Dublin City, Ireland]              NaN
#
#    neighborhood                        id
# 0           NaN  4ba3a0b7f964a5208c4d38e3
# 1           NaN  4bbe0eb2c6a2ef3be336ddbd
# 2           NaN  50899302e4b0ddcb6cfa89ff
# 3           NaN  4fe4e0f6e4b08674c9cb2716
# 4           NaN  50ca02c2245f2d4aa8c2ba6b
# 5           NaN  4b05afdcf964a520f8e022e3
# 6           NaN  4bab3531f964a52083993ae3
# 7           NaN  5171c0c9e4b04c634eb476e8
# 8           NaN  51450c55e4b0df0d72b2ccc9
# 9           NaN  4af4a6cbf964a520b2f421e3
# 10          NaN  4d502c614015b1f7c1ac63cf
# 11          NaN  530e8e9b498e8e842d1c3b7f
# 12          NaN  4cf69320e308236a29f7e6ac
# 13          NaN  5d6bdeab2c61ca0008aa38d5
# 14          NaN  58c31a706ad73d0d9980ba1b
# 15          NaN  5058da13e4b0a3bd5566fd12
# 16          NaN  57daef8ecd104981a7e6394e
# 17  Dublin City  56f3f7a5498ea87d6d8d2850
# 18          NaN  51ec042d498e00bc1d40f2f5
# 19          NaN  52876ce211d2f357d91145f9
# 20          NaN  4ce589dedfaef04d39a56e83
# 21          NaN  517171a6e4b0978a47f4ca8a
# 22          NaN  50509ff8e4b0473d5f54cd7b
# 23          NaN  52873bbf11d248c7de2a4c77
# 24          NaN  511676dee4b0ec5107171946
# 25          NaN  5041eb01e4b0591b22da6a45
# 26          NaN  517284bfe4b0745535058072
# 27          NaN  5502eece498edcf46c4fe813
# 28          NaN  4f3f7994e4b0f13aa602cb7e
# 29          NaN  510bb81ce4b077915ef76d03
# 30          NaN  5409b101498eaf564c42fff6
# 31          NaN  4af9f82af964a520a71522e3
# 32          NaN  5ae338e9acb00b002c44021d
# 33          NaN  4d32fc065c2db60ce220c76c
# 34          NaN  58e78b740acb6a688a378733
# 35          NaN  4d82472f5b942c0ff6f7a5f1
# 36          NaN  4e1878e62271b0e971fc30aa
# 37          NaN  572c7fb7498edf83df0e9ed6
# 38          NaN  4c87e7b318209521e1d2aeef

# %%
dataframe_filtered=pd.DataFrame(dataframe_filtered)

dublinBar_map = folium.Map(location=[latitude, longitude], zoom_start=12) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(dublinBar_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['categories']):
    label = '{}, {}'.format(dataframe_filtered['id'], dataframe_filtered['distance'])
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(dublinBar_map) 

# display map
dublinBar_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 9. Searching for Bars in 40 Dawson St, Dublin, Ireland

# %%
address1 = "40 Dawson St, Dublin, Irlanda"

geolocator = Nominatim(user_agent="dublin1_agent")
location = geolocator.geocode(address1)
latitude1 = location.latitude
longitude1 = location.longitude
print(latitude1, longitude1)
# Out:
# 53.3407499 -6.25907377754813

# %%
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, search_query, radius, LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2ECMKGACQRNDAOTLP02N52AXE5A0AUCMK5RBWF5TWHSBLI41&client_secret=CGYL4DFESDX1MSNLQBTPV2WAFV4FABLQ5WZS2IODNVQ0LDAX&ll=53.3407499,-6.25907377754813&v=20180604&query=Bar&radius=1000&limit=1000'

# %%
result2 = requests.get(url2).json()
result2
# Out:
# {'meta': {'code': 200, 'requestId': '5f149c1288f1c343fd0a37bf'},
#  'response': {'venues': [{'id': '4ade0eedf964a520767021e3',
#     'name': 'La Cave Wine Bar',
#     'location': {'address': '28 S Anne St',
#      'lat': 53.341118114213074,
#      'lng': -6.259603809296415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.341118114213074,
#        'lng': -6.259603809296415}],
#      'distance': 54,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['28 S Anne St', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'shortName': 'Wine Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0f35f964a5207d7121e3',
#     'name': 'Captain Americas Cookhouse & Bar',
#     'location': {'address': '44 Grafton St',
#      'lat': 53.34051129617559,
#      'lng': -6.260500468380906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34051129617559,
#        'lng': -6.260500468380906}],
#      'distance': 98,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['44 Grafton St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '53097925'},
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0f0bf964a520ea7021e3',
#     'name': "Sam's Bar",
#     'location': {'address': '36 Dawson St',
#      'lat': 53.340476585054866,
#      'lng': -6.2591281486190855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.340476585054866,
#        'lng': -6.2591281486190855}],
#      'distance': 30,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['36 Dawson St', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '5409de55498e23475796305c',
#     'name': 'Kokoro Bento - The Ramen Bar',
#     'location': {'address': '51 S William St',
#      'lat': 53.34161031356423,
#      'lng': -6.26277336188155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34161031356423,
#        'lng': -6.26277336188155}],
#      'distance': 263,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['51 S William St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '55a59bace4b013909087cb24',
#       'name': 'Ramen Restaurant',
#       'pluralName': 'Ramen Restaurants',
#       'shortName': 'Ramen',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0efdf964a520ab7021e3',
#     'name': "O'Neills Bar & Restaurant",
#     'location': {'address': '2 Suffolk St',
#      'lat': 53.3438681996721,
#      'lng': -6.260812378967063,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.3438681996721,
#        'lng': -6.260812378967063}],
#      'distance': 365,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['2 Suffolk St', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0ef1f964a520847021e3',
#     'name': 'Bailey Bar Dublin',
#     'location': {'address': 'Duke St',
#      'lat': 53.341963651257714,
#      'lng': -6.259444794513737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.341963651257714,
#        'lng': -6.259444794513737}],
#      'distance': 137,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Duke St', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '143072717'},
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4b9adba1f964a520d2dc35e3',
#     'name': "Olesya's Wine Bar",
#     'location': {'address': '18 Exchequer St',
#      'lat': 53.34301650569698,
#      'lng': -6.263167338293554,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34301650569698,
#        'lng': -6.263167338293554}],
#      'distance': 371,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['18 Exchequer St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'shortName': 'Wine Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0ef0f964a520817021e3',
#     'name': 'The Temple Bar',
#     'location': {'address': '47-48 Temple Bar',
#      'lat': 53.3454766557522,
#      'lng': -6.264191652531398,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.3454766557522,
#        'lng': -6.264191652531398}],
#      'distance': 626,
#      'postalCode': '2',
#      'cc': 'IE',
#      'neighborhood': 'Temple Bar',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['47-48 Temple Bar',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0ef2f964a520877021e3',
#     'name': "Brown's Bar & Cafe",
#     'location': {'address': 'Brown Thomas, 88-95 Grafton St',
#      'lat': 53.34259876014952,
#      'lng': -6.260055472826646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34259876014952,
#        'lng': -6.260055472826646}],
#      'distance': 215,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Brown Thomas, 88-95 Grafton St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0f09f964a520e17021e3',
#     'name': 'No 27 Bar & Lounge',
#     'location': {'address': "The Shelbourne Hotel, 27 St Stephen's Green",
#      'lat': 53.33901127111491,
#      'lng': -6.256318491162427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33901127111491,
#        'lng': -6.256318491162427}],
#      'distance': 266,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ["The Shelbourne Hotel, 27 St Stephen's Green",
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '547b8b03498e3bbc4618dd6a',
#     'name': 'Dingle Whiskey Bar',
#     'location': {'address': '44 Nassau St',
#      'lat': 53.34312610942346,
#      'lng': -6.258752552668774,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34312610942346,
#        'lng': -6.258752552668774}],
#      'distance': 265,
#      'cc': 'IE',
#      'neighborhood': 'Trinity College Dublin',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['44 Nassau St', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d122941735',
#       'name': 'Whisky Bar',
#       'pluralName': 'Whisky Bars',
#       'shortName': 'Whisky Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/whiskey_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4c1421a27f7f2d7fc96ae068',
#     'name': 'The Horseshoe Bar',
#     'location': {'address': "The Shelbourne Hotel, St Stephen's Green",
#      'lat': 53.338829785368944,
#      'lng': -6.25607394731282,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.338829785368944,
#        'lng': -6.25607394731282}],
#      'distance': 292,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ["The Shelbourne Hotel, St Stephen's Green",
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4af7375cf964a5203c0722e3',
#     'name': "Bar with No Name / Bar No.3 / Kelly's / The Snail",
#     'location': {'address': '3 Fade St',
#      'lat': 53.3419357885594,
#      'lng': -6.264289847369917,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.3419357885594,
#        'lng': -6.264289847369917}],
#      'distance': 370,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['3 Fade St', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4c167de296040f477ced72a5',
#     'name': 'Bar Italia Restaurant',
#     'location': {'address': '26 Lower Ormond Quay',
#      'lat': 53.346165064104646,
#      'lng': -6.264891418380056,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.346165064104646,
#        'lng': -6.264891418380056}],
#      'distance': 716,
#      'postalCode': '1',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['26 Lower Ormond Quay',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0f29f964a5204d7121e3',
#     'name': 'Temple Bar Gallery + Studios',
#     'location': {'address': '5-9 Temple Bar',
#      'lat': 53.345624140154776,
#      'lng': -6.263431415000435,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.345624140154776,
#        'lng': -6.263431415000435}],
#      'distance': 615,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['5-9 Temple Bar',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ffe9011e4b021eb8b8ad6f6',
#     'name': 'Expert Bar @ Compu b',
#     'location': {'address': '111 Grafton St',
#      'lat': 53.343727,
#      'lng': -6.259275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.343727,
#        'lng': -6.259275}],
#      'distance': 331,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['111 Grafton St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d122951735',
#       'name': 'Electronics Store',
#       'pluralName': 'Electronics Stores',
#       'shortName': 'Electronics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4fef5afde4b0660372575a48',
#     'name': 'Bison Bar & BBQ',
#     'location': {'address': '11 Wellington Quay',
#      'lat': 53.34542138294974,
#      'lng': -6.266350038073391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34542138294974,
#        'lng': -6.266350038073391}],
#      'distance': 710,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['11 Wellington Quay',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0f0bf964a520e97021e3',
#     'name': 'The Library Bar',
#     'location': {'address': '2 Exchequer St',
#      'lat': 53.34302832819316,
#      'lng': -6.264286368952781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34302832819316,
#        'lng': -6.264286368952781}],
#      'distance': 429,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['2 Exchequer St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '69182782'},
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4af814edf964a520e80a22e3',
#     'name': 'Ukiyo Bar',
#     'location': {'address': '7-9 Exchequer St',
#      'lat': 53.34304618866043,
#      'lng': -6.263695888601069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34304618866043,
#        'lng': -6.263695888601069}],
#      'distance': 399,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['7-9 Exchequer St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4af5f828f964a5209dff21e3',
#     'name': "Hogan's Bar",
#     'location': {'address': '35 S Great Georges St',
#      'lat': 53.34207529764807,
#      'lng': -6.264643878713559,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34207529764807,
#        'lng': -6.264643878713559}],
#      'distance': 398,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['35 S Great Georges St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '55073bab498ebefdee03e118',
#     'name': 'Bonsai Bar',
#     'location': {'lat': 53.342918395996094,
#      'lng': -6.264134883880615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.342918395996094,
#        'lng': -6.264134883880615}],
#      'distance': 414,
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '5638fee3cd104e8bcdf6eb34',
#     'name': "Oscar's Bar & Kitchen",
#     'location': {'address': '1-4 Merrion St Lwr',
#      'lat': 53.341344,
#      'lng': -6.251135,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.341344,
#        'lng': -6.251135}],
#      'distance': 531,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['1-4 Merrion St Lwr', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'shortName': 'Gastropub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4b71fd6ff964a520b7682de3',
#     'name': 'The Mercantile Bar & Grill',
#     'location': {'address': '50-53 Dame St',
#      'lat': 53.34413506914928,
#      'lng': -6.264072804642472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34413506914928,
#        'lng': -6.264072804642472}],
#      'distance': 502,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['50-53 Dame St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '57116c4b498e0859ea3dae93',
#     'name': 'No.5 Piano & Cocktail Bar',
#     'location': {'lat': 53.337506,
#      'lng': -6.255106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.337506,
#        'lng': -6.255106}],
#      'distance': 447,
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e8931735',
#       'name': 'Piano Bar',
#       'pluralName': 'Piano Bars',
#       'shortName': 'Piano Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_pianobar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4b88135af964a520e7dd31e3',
#     'name': 'The Cellar Bar',
#     'location': {'address': 'The Merrion Hotel, Uppr Merrion St',
#      'lat': 53.33873930127713,
#      'lng': -6.252876140259834,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33873930127713,
#        'lng': -6.252876140259834}],
#      'distance': 468,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['The Merrion Hotel, Uppr Merrion St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '64601682'},
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0f07f964a520d67021e3',
#     'name': 'Citi Bar & Venue',
#     'location': {'address': '46 Dame Street',
#      'lat': 53.34425043549996,
#      'lng': -6.2636408108825625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34425043549996,
#        'lng': -6.2636408108825625}],
#      'distance': 493,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['46 Dame Street',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4b5b0e4ef964a5202ee128e3',
#     'name': 'Temple Bar Food Market',
#     'location': {'address': 'Meeting House Sq',
#      'lat': 53.34501758326336,
#      'lng': -6.265356941751806,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34501758326336,
#        'lng': -6.265356941751806}],
#      'distance': 632,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Meeting House Sq',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1fa941735',
#       'name': 'Farmers Market',
#       'pluralName': 'Farmers Markets',
#       'shortName': "Farmer's Market",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '5a6cc25d356b4950ef9a247b',
#     'name': 'The Key Collection Temple Bar',
#     'location': {'address': '5 Crow St.',
#      'lat': 53.344707,
#      'lng': -6.263868,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.344707,
#        'lng': -6.263868}],
#      'distance': 543,
#      'cc': 'IE',
#      'neighborhood': 'Temple Bar',
#      'city': 'Δουβλίνο',
#      'country': 'Ireland',
#      'formattedAddress': ['5 Crow St.', 'Δουβλίνο', 'Ireland']},
#     'categories': [{'id': '56aa371be4b08b9a8d5734e1',
#       'name': 'Vacation Rental',
#       'pluralName': 'Vacation Rentals',
#       'shortName': 'Vacation Rental',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '52b1fc53498ef2068fb1ef7f',
#     'name': 'Quays Bar',
#     'location': {'address': '12 Temple Bar',
#      'lat': 53.345557383732505,
#      'lng': -6.263108634780885,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.345557383732505,
#        'lng': -6.263108634780885}],
#      'distance': 598,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['12 Temple Bar',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '5daca02318e43d0007e521f3',
#     'name': 'Molly Malone’s Temple Bar',
#     'location': {'address': '4 Temple Ln S, Temple Bar',
#      'lat': 53.344909,
#      'lng': -6.265476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.344909,
#        'lng': -6.265476}],
#      'distance': 628,
#      'postalCode': 'DUBLIN 2',
#      'cc': 'IE',
#      'city': 'Dublín',
#      'country': 'Ireland',
#      'formattedAddress': ['4 Temple Ln S, Temple Bar', 'Dublín', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4b9cdbcaf964a520147f36e3',
#     'name': 'IFI Café Bar',
#     'location': {'address': '6 Eustace St, Temple Bar',
#      'lat': 53.344666930998,
#      'lng': -6.265236492841581,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.344666930998,
#        'lng': -6.265236492841581}],
#      'distance': 598,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['6 Eustace St, Temple Bar',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4d64f43c601d88bfd5a8bebb',
#     'name': 'Temple Bar Jewellers',
#     'location': {'address': '27 Eustace St.',
#      'lat': 53.344518106666435,
#      'lng': -6.264803409576416,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.344518106666435,
#        'lng': -6.264803409576416}],
#      'distance': 566,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['27 Eustace St.',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'shortName': 'Jewelry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4cfbb0f2d8468cfaa3fff56b',
#     'name': "Merchant's Arch Bar & Restaurant",
#     'location': {'address': '48-49 Wellington Quay',
#      'lat': 53.34642196575516,
#      'lng': -6.26305531042032,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34642196575516,
#        'lng': -6.26305531042032}],
#      'distance': 684,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['48-49 Wellington Quay',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '50b6433ae4b0a4380b8f7d37',
#     'name': 'Temple Bar / Barra an Teampaill',
#     'location': {'lat': 53.3453721176235,
#      'lng': -6.264738568496673,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.3453721176235,
#        'lng': -6.264738568496673}],
#      'distance': 637,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4f2a25ac4b909258e854f55f',
#       'name': 'Neighborhood',
#       'pluralName': 'Neighborhoods',
#       'shortName': 'Neighborhood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0ef1f964a520857021e3',
#     'name': 'The Octagon Bar',
#     'location': {'address': 'The Clarence, 6-8 Wellington Quay',
#      'lat': 53.345296457453415,
#      'lng': -6.266679494957592,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.345296457453415,
#        'lng': -6.266679494957592}],
#      'distance': 715,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['The Clarence, 6-8 Wellington Quay',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4b7be483f964a52072722fe3',
#     'name': 'Temple Bar Information Centre',
#     'location': {'address': '12 E Essex St',
#      'lat': 53.34522266586595,
#      'lng': -6.265833377838135,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34522266586595,
#        'lng': -6.265833377838135}],
#      'distance': 670,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['12 E Essex St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4f4530164b9074f6e4fb00ff',
#       'name': 'Tourist Information Center',
#       'pluralName': 'Tourist Information Centers',
#       'shortName': 'Tourist Information',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/touristinformation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0eeef964a520797021e3',
#     'name': 'Harbour Master Bar & Restaurant',
#     'location': {'address': 'Customs House Dock',
#      'crossStreet': 'IFSC',
#      'lat': 53.34976625270294,
#      'lng': -6.249087468685069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34976625270294,
#        'lng': -6.249087468685069}],
#      'distance': 1203,
#      'postalCode': '1',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Customs House Dock (IFSC)',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '61773275'},
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4e0fe3fe7d8b4d5613cd8853',
#     'name': 'Temple Bar Emporium',
#     'location': {'address': '20 Crane Ln',
#      'lat': 53.34441726327917,
#      'lng': -6.26683822930448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34441726327917,
#        'lng': -6.26683822930448}],
#      'distance': 657,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['20 Crane Ln', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d6941735',
#       'name': 'Strip Club',
#       'pluralName': 'Strip Clubs',
#       'shortName': 'Strip Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/stripclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '50b33907e4b0dabb595a65f8',
#     'name': 'The Temple Bar Company',
#     'location': {'address': '2-5 Wellington Quay',
#      'lat': 53.345336,
#      'lng': -6.267083,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.345336,
#        'lng': -6.267083}],
#      'distance': 737,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['2-5 Wellington Quay',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4b31158bf964a520ceff24e3',
#     'name': "O'Reilly's Bar",
#     'location': {'address': 'Tara St DART Station',
#      'lat': 53.34699721337132,
#      'lng': -6.25406804446125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34699721337132,
#        'lng': -6.25406804446125}],
#      'distance': 770,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Tara St DART Station',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4b013fd7f964a520eb4122e3',
#     'name': 'Grand Central Bar',
#     'location': {'address': "42-44 O'Connell St Lwr",
#      'lat': 53.348497372219015,
#      'lng': -6.25925102558867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.348497372219015,
#        'lng': -6.25925102558867}],
#      'distance': 862,
#      'postalCode': '1',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ["42-44 O'Connell St Lwr",
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '50bdf9d5e4b090d00b4ad81b',
#     'name': 'Wokin Noodle Bar',
#     'location': {'address': '6 Millennium Walkway',
#      'lat': 53.34727343486594,
#      'lng': -6.265513959491842,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34727343486594,
#        'lng': -6.265513959491842}],
#      'distance': 842,
#      'postalCode': '1',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['6 Millennium Walkway',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '54557bff498eee46cdfe7ea3',
#     'name': 'The Bourbon Bar',
#     'location': {'address': 'Odeon, Harcourt St',
#      'lat': 53.33342805809801,
#      'lng': -6.262569994382686,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33342805809801,
#        'lng': -6.262569994382686}],
#      'distance': 847,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Odeon, Harcourt St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '557480c7498eedcbad681a09',
#     'name': 'Oscars Café Bar',
#     'location': {'address': '16-18 Fishamble St',
#      'lat': 53.34421106151204,
#      'lng': -6.269929537232648,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34421106151204,
#        'lng': -6.269929537232648}],
#      'distance': 817,
#      'postalCode': '8',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['16-18 Fishamble St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4d0b5faad823b1f7e2f9e85c',
#     'name': 'The Central Bar',
#     'location': {'address': 'Camden Court Hotel',
#      'crossStreet': 'Camden St',
#      'lat': 53.333101134963464,
#      'lng': -6.264951005972565,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.333101134963464,
#        'lng': -6.264951005972565}],
#      'distance': 936,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Camden Court Hotel (Camden St)',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4f3f99cae4b0ae065538fe3d',
#     'name': 'Nail Bar',
#     'location': {'address': '1st Flor, Jervis Street Shopping Centre',
#      'lat': 53.34847,
#      'lng': -6.2659,
#      'labeledLatLngs': [{'label': 'display', 'lat': 53.34847, 'lng': -6.2659}],
#      'distance': 971,
#      'postalCode': '1',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['1st Flor, Jervis Street Shopping Centre',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'shortName': 'Nail Salon',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4ade0f06f964a520d07021e3',
#     'name': 'Fire Steakhouse & Bar',
#     'location': {'address': 'The Mansion House, Dawson St',
#      'lat': 53.34050800862686,
#      'lng': -6.257911926533321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.34050800862686,
#        'lng': -6.257911926533321}],
#      'distance': 81,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['The Mansion House, Dawson St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '566c88f5498e1bdb151fc2e9',
#     'name': 'The Seafood Bar',
#     'location': {'address': 'La Stampa Hotel, Dawson St',
#      'lat': 53.340387009808836,
#      'lng': -6.259367249833629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.340387009808836,
#        'lng': -6.259367249833629}],
#      'distance': 44,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['La Stampa Hotel, Dawson St',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '4bf6c2705ec320a1a6b485d3',
#     'name': "M O'Brien's Bar & Lounge",
#     'location': {'address': 'Sussex Tce',
#      'lat': 53.33129413460899,
#      'lng': -6.251571808386853,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33129413460899,
#        'lng': -6.251571808386853}],
#      'distance': 1164,
#      'postalCode': '4',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Sussex Tce', 'Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False},
#    {'id': '50ca02c6245f2d4aa8c2c910',
#     'name': 'Charlemont Bar & Bistro',
#     'location': {'address': 'Hilton Dublin, Charlemont Pl',
#      'lat': 53.33084512377578,
#      'lng': -6.2592441594535035,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.33084512377578,
#        'lng': -6.2592441594535035}],
#      'distance': 1102,
#      'postalCode': '2',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Hilton Dublin, Charlemont Pl',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186622',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venue1Bar = result2['response']['venues']

# tranform venues into a dataframe
data1Bar = json_normalize(venue1Bar)
data1Bar.head()
# Out:
# /home/greyce/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                              name  \
# 0  4ade0eedf964a520767021e3                  La Cave Wine Bar
# 1  4ade0f35f964a5207d7121e3  Captain Americas Cookhouse & Bar
# 2  4ade0f0bf964a520ea7021e3                         Sam's Bar
# 3  5409de55498e23475796305c      Kokoro Bento - The Ramen Bar
# 4  4ade0efdf964a520ab7021e3         O'Neills Bar & Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...  v-1595186622    False
# 1  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1595186622    False
# 2  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1595186622    False
# 3  [{'id': '55a59bace4b013909087cb24', 'name': 'R...  v-1595186622    False
# 4  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1595186622    False
#
#   location.address  location.lat  location.lng  \
# 0     28 S Anne St     53.341118     -6.259604
# 1    44 Grafton St     53.340511     -6.260500
# 2     36 Dawson St     53.340477     -6.259128
# 3  51 S William St     53.341610     -6.262773
# 4     2 Suffolk St     53.343868     -6.260812
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 53.34111811421307...                 54
# 1  [{'label': 'display', 'lat': 53.34051129617559...                 98
# 2  [{'label': 'display', 'lat': 53.34047658505486...                 30
# 3  [{'label': 'display', 'lat': 53.34161031356423...                263
# 4  [{'label': 'display', 'lat': 53.3438681996721,...                365
#
#   location.postalCode location.cc location.city location.state  \
# 0                   2          IE        Dublin    Dublin City
# 1                   2          IE        Dublin    Dublin City
# 2                   2          IE        Dublin    Dublin City
# 3                   2          IE        Dublin    Dublin City
# 4                   2          IE        Dublin    Dublin City
#
#   location.country                        location.formattedAddress  \
# 0          Ireland     [28 S Anne St, Dublin, Dublin City, Ireland]
# 1          Ireland    [44 Grafton St, Dublin, Dublin City, Ireland]
# 2          Ireland     [36 Dawson St, Dublin, Dublin City, Ireland]
# 3          Ireland  [51 S William St, Dublin, Dublin City, Ireland]
# 4          Ireland     [2 Suffolk St, Dublin, Dublin City, Ireland]
#
#   venuePage.id location.neighborhood location.crossStreet
# 0          NaN                   NaN                  NaN
# 1     53097925                   NaN                  NaN
# 2          NaN                   NaN                  NaN
# 3          NaN                   NaN                  NaN
# 4          NaN                   NaN                  NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in data1Bar.columns if col.startswith('location.')] + ['id']
dataframe_filtered = data1Bar.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                    La Cave Wine Bar
# 1                    Captain Americas Cookhouse & Bar
# 2                                           Sam's Bar
# 3                        Kokoro Bento - The Ramen Bar
# 4                           O'Neills Bar & Restaurant
# 5                                   Bailey Bar Dublin
# 6                                   Olesya's Wine Bar
# 7                                      The Temple Bar
# 8                                  Brown's Bar & Cafe
# 9                                  No 27 Bar & Lounge
# 10                                 Dingle Whiskey Bar
# 11                                  The Horseshoe Bar
# 12  Bar with No Name / Bar No.3 / Kelly's / The Snail
# 13                              Bar Italia Restaurant
# 14                       Temple Bar Gallery + Studios
# 15                               Expert Bar @ Compu b
# 16                                    Bison Bar & BBQ
# 17                                    The Library Bar
# 18                                          Ukiyo Bar
# 19                                        Hogan's Bar
# 20                                         Bonsai Bar
# 21                              Oscar's Bar & Kitchen
# 22                         The Mercantile Bar & Grill
# 23                          No.5 Piano & Cocktail Bar
# 24                                     The Cellar Bar
# 25                                   Citi Bar & Venue
# 26                             Temple Bar Food Market
# 27                      The Key Collection Temple Bar
# 28                                          Quays Bar
# 29                          Molly Malone’s Temple Bar
# 30                                       IFI Café Bar
# 31                               Temple Bar Jewellers
# 32                   Merchant's Arch Bar & Restaurant
# 33                    Temple Bar / Barra an Teampaill
# 34                                    The Octagon Bar
# 35                      Temple Bar Information Centre
# 36                    Harbour Master Bar & Restaurant
# 37                                Temple Bar Emporium
# 38                             The Temple Bar Company
# 39                                     O'Reilly's Bar
# 40                                  Grand Central Bar
# 41                                   Wokin Noodle Bar
# 42                                    The Bourbon Bar
# 43                                    Oscars Café Bar
# 44                                    The Central Bar
# 45                                           Nail Bar
# 46                              Fire Steakhouse & Bar
# 47                                    The Seafood Bar
# 48                           M O'Brien's Bar & Lounge
# 49                            Charlemont Bar & Bistro
#
#                     categories                                      address  \
# 0                     Wine Bar                                 28 S Anne St
# 1          American Restaurant                                44 Grafton St
# 2                          Bar                                 36 Dawson St
# 3             Ramen Restaurant                              51 S William St
# 4                          Pub                                 2 Suffolk St
# 5                          Pub                                      Duke St
# 6                     Wine Bar                              18 Exchequer St
# 7                          Pub                             47-48 Temple Bar
# 8                  Coffee Shop               Brown Thomas, 88-95 Grafton St
# 9                    Hotel Bar  The Shelbourne Hotel, 27 St Stephen's Green
# 10                  Whisky Bar                                 44 Nassau St
# 11                   Hotel Bar     The Shelbourne Hotel, St Stephen's Green
# 12                         Pub                                    3 Fade St
# 13          Italian Restaurant                         26 Lower Ormond Quay
# 14                 Art Gallery                               5-9 Temple Bar
# 15           Electronics Store                               111 Grafton St
# 16                         Pub                           11 Wellington Quay
# 17                   Hotel Bar                               2 Exchequer St
# 18         Japanese Restaurant                             7-9 Exchequer St
# 19                         Pub                        35 S Great Georges St
# 20                Cocktail Bar                                          NaN
# 21                   Gastropub                           1-4 Merrion St Lwr
# 22                         Pub                                50-53 Dame St
# 23                   Piano Bar                                          NaN
# 24                   Hotel Bar           The Merrion Hotel, Uppr Merrion St
# 25                         Pub                               46 Dame Street
# 26              Farmers Market                             Meeting House Sq
# 27             Vacation Rental                                   5 Crow St.
# 28                         Pub                                12 Temple Bar
# 29                         Bar                    4 Temple Ln S, Temple Bar
# 30                         Bar                     6 Eustace St, Temple Bar
# 31               Jewelry Store                               27 Eustace St.
# 32                         Pub                        48-49 Wellington Quay
# 33                Neighborhood                                          NaN
# 34                   Hotel Bar            The Clarence, 6-8 Wellington Quay
# 35  Tourist Information Center                                12 E Essex St
# 36                         Bar                           Customs House Dock
# 37                  Strip Club                                  20 Crane Ln
# 38                      Office                          2-5 Wellington Quay
# 39                         Pub                         Tara St DART Station
# 40                         Bar                       42-44 O'Connell St Lwr
# 41            Asian Restaurant                         6 Millennium Walkway
# 42                   Nightclub                           Odeon, Harcourt St
# 43                         Bar                           16-18 Fishamble St
# 44                         Bar                           Camden Court Hotel
# 45                  Nail Salon      1st Flor, Jervis Street Shopping Centre
# 46                  Restaurant                 The Mansion House, Dawson St
# 47                  Restaurant                   La Stampa Hotel, Dawson St
# 48                         Pub                                   Sussex Tce
# 49                   Hotel Bar                 Hilton Dublin, Charlemont Pl
#
#           lat       lng                                     labeledLatLngs  \
# 0   53.341118 -6.259604  [{'label': 'display', 'lat': 53.34111811421307...
# 1   53.340511 -6.260500  [{'label': 'display', 'lat': 53.34051129617559...
# 2   53.340477 -6.259128  [{'label': 'display', 'lat': 53.34047658505486...
# 3   53.341610 -6.262773  [{'label': 'display', 'lat': 53.34161031356423...
# 4   53.343868 -6.260812  [{'label': 'display', 'lat': 53.3438681996721,...
# 5   53.341964 -6.259445  [{'label': 'display', 'lat': 53.34196365125771...
# 6   53.343017 -6.263167  [{'label': 'display', 'lat': 53.34301650569698...
# 7   53.345477 -6.264192  [{'label': 'display', 'lat': 53.3454766557522,...
# 8   53.342599 -6.260055  [{'label': 'display', 'lat': 53.34259876014952...
# 9   53.339011 -6.256318  [{'label': 'display', 'lat': 53.33901127111491...
# 10  53.343126 -6.258753  [{'label': 'display', 'lat': 53.34312610942346...
# 11  53.338830 -6.256074  [{'label': 'display', 'lat': 53.33882978536894...
# 12  53.341936 -6.264290  [{'label': 'display', 'lat': 53.3419357885594,...
# 13  53.346165 -6.264891  [{'label': 'display', 'lat': 53.34616506410464...
# 14  53.345624 -6.263431  [{'label': 'display', 'lat': 53.34562414015477...
# 15  53.343727 -6.259275  [{'label': 'display', 'lat': 53.343727, 'lng':...
# 16  53.345421 -6.266350  [{'label': 'display', 'lat': 53.34542138294974...
# 17  53.343028 -6.264286  [{'label': 'display', 'lat': 53.34302832819316...
# 18  53.343046 -6.263696  [{'label': 'display', 'lat': 53.34304618866043...
# 19  53.342075 -6.264644  [{'label': 'display', 'lat': 53.34207529764807...
# 20  53.342918 -6.264135  [{'label': 'display', 'lat': 53.34291839599609...
# 21  53.341344 -6.251135  [{'label': 'display', 'lat': 53.341344, 'lng':...
# 22  53.344135 -6.264073  [{'label': 'display', 'lat': 53.34413506914928...
# 23  53.337506 -6.255106  [{'label': 'display', 'lat': 53.337506, 'lng':...
# 24  53.338739 -6.252876  [{'label': 'display', 'lat': 53.33873930127713...
# 25  53.344250 -6.263641  [{'label': 'display', 'lat': 53.34425043549996...
# 26  53.345018 -6.265357  [{'label': 'display', 'lat': 53.34501758326336...
# 27  53.344707 -6.263868  [{'label': 'display', 'lat': 53.344707, 'lng':...
# 28  53.345557 -6.263109  [{'label': 'display', 'lat': 53.34555738373250...
# 29  53.344909 -6.265476  [{'label': 'display', 'lat': 53.344909, 'lng':...
# 30  53.344667 -6.265236  [{'label': 'display', 'lat': 53.344666930998, ...
# 31  53.344518 -6.264803  [{'label': 'display', 'lat': 53.34451810666643...
# 32  53.346422 -6.263055  [{'label': 'display', 'lat': 53.34642196575516...
# 33  53.345372 -6.264739  [{'label': 'display', 'lat': 53.3453721176235,...
# 34  53.345296 -6.266679  [{'label': 'display', 'lat': 53.34529645745341...
# 35  53.345223 -6.265833  [{'label': 'display', 'lat': 53.34522266586595...
# 36  53.349766 -6.249087  [{'label': 'display', 'lat': 53.34976625270294...
# 37  53.344417 -6.266838  [{'label': 'display', 'lat': 53.34441726327917...
# 38  53.345336 -6.267083  [{'label': 'display', 'lat': 53.345336, 'lng':...
# 39  53.346997 -6.254068  [{'label': 'display', 'lat': 53.34699721337132...
# 40  53.348497 -6.259251  [{'label': 'display', 'lat': 53.34849737221901...
# 41  53.347273 -6.265514  [{'label': 'display', 'lat': 53.34727343486594...
# 42  53.333428 -6.262570  [{'label': 'display', 'lat': 53.33342805809801...
# 43  53.344211 -6.269930  [{'label': 'display', 'lat': 53.34421106151204...
# 44  53.333101 -6.264951  [{'label': 'display', 'lat': 53.33310113496346...
# 45  53.348470 -6.265900  [{'label': 'display', 'lat': 53.34847, 'lng': ...
# 46  53.340508 -6.257912  [{'label': 'display', 'lat': 53.34050800862686...
# 47  53.340387 -6.259367  [{'label': 'display', 'lat': 53.34038700980883...
# 48  53.331294 -6.251572  [{'label': 'display', 'lat': 53.33129413460899...
# 49  53.330845 -6.259244  [{'label': 'display', 'lat': 53.33084512377578...
#
#     distance postalCode  cc      city        state  country  \
# 0         54          2  IE    Dublin  Dublin City  Ireland
# 1         98          2  IE    Dublin  Dublin City  Ireland
# 2         30          2  IE    Dublin  Dublin City  Ireland
# 3        263          2  IE    Dublin  Dublin City  Ireland
# 4        365          2  IE    Dublin  Dublin City  Ireland
# 5        137          2  IE    Dublin  Dublin City  Ireland
# 6        371          2  IE    Dublin  Dublin City  Ireland
# 7        626          2  IE    Dublin  Dublin City  Ireland
# 8        215          2  IE    Dublin  Dublin City  Ireland
# 9        266          2  IE    Dublin  Dublin City  Ireland
# 10       265        NaN  IE    Dublin  Dublin City  Ireland
# 11       292          2  IE    Dublin  Dublin City  Ireland
# 12       370          2  IE    Dublin  Dublin City  Ireland
# 13       716          1  IE    Dublin  Dublin City  Ireland
# 14       615          2  IE    Dublin  Dublin City  Ireland
# 15       331          2  IE    Dublin  Dublin City  Ireland
# 16       710          2  IE    Dublin  Dublin City  Ireland
# 17       429          2  IE    Dublin  Dublin City  Ireland
# 18       399          2  IE    Dublin  Dublin City  Ireland
# 19       398          2  IE    Dublin  Dublin City  Ireland
# 20       414        NaN  IE    Dublin  Dublin City  Ireland
# 21       531        NaN  IE       NaN          NaN  Ireland
# 22       502          2  IE    Dublin  Dublin City  Ireland
# 23       447        NaN  IE    Dublin  Dublin City  Ireland
# 24       468          2  IE    Dublin  Dublin City  Ireland
# 25       493          2  IE    Dublin  Dublin City  Ireland
# 26       632          2  IE    Dublin  Dublin City  Ireland
# 27       543        NaN  IE  Δουβλίνο          NaN  Ireland
# 28       598          2  IE    Dublin  Dublin City  Ireland
# 29       628   DUBLIN 2  IE    Dublín          NaN  Ireland
# 30       598          2  IE    Dublin  Dublin City  Ireland
# 31       566          2  IE    Dublin  Dublin City  Ireland
# 32       684          2  IE    Dublin  Dublin City  Ireland
# 33       637          2  IE    Dublin  Dublin City  Ireland
# 34       715          2  IE    Dublin  Dublin City  Ireland
# 35       670          2  IE    Dublin  Dublin City  Ireland
# 36      1203          1  IE    Dublin  Dublin City  Ireland
# 37       657          2  IE    Dublin  Dublin City  Ireland
# 38       737          2  IE    Dublin  Dublin City  Ireland
# 39       770          2  IE    Dublin  Dublin City  Ireland
# 40       862          1  IE    Dublin  Dublin City  Ireland
# 41       842          1  IE    Dublin  Dublin City  Ireland
# 42       847          2  IE    Dublin  Dublin City  Ireland
# 43       817          8  IE    Dublin  Dublin City  Ireland
# 44       936          2  IE    Dublin  Dublin City  Ireland
# 45       971          1  IE    Dublin  Dublin City  Ireland
# 46        81          2  IE    Dublin  Dublin City  Ireland
# 47        44          2  IE    Dublin  Dublin City  Ireland
# 48      1164          4  IE    Dublin  Dublin City  Ireland
# 49      1102          2  IE    Dublin  Dublin City  Ireland
#
#                                      formattedAddress            neighborhood  \
# 0        [28 S Anne St, Dublin, Dublin City, Ireland]                     NaN
# 1       [44 Grafton St, Dublin, Dublin City, Ireland]                     NaN
# 2        [36 Dawson St, Dublin, Dublin City, Ireland]                     NaN
# 3     [51 S William St, Dublin, Dublin City, Ireland]                     NaN
# 4        [2 Suffolk St, Dublin, Dublin City, Ireland]                     NaN
# 5             [Duke St, Dublin, Dublin City, Ireland]                     NaN
# 6     [18 Exchequer St, Dublin, Dublin City, Ireland]                     NaN
# 7    [47-48 Temple Bar, Dublin, Dublin City, Ireland]              Temple Bar
# 8   [Brown Thomas, 88-95 Grafton St, Dublin, Dubli...                     NaN
# 9   [The Shelbourne Hotel, 27 St Stephen's Green, ...                     NaN
# 10       [44 Nassau St, Dublin, Dublin City, Ireland]  Trinity College Dublin
# 11  [The Shelbourne Hotel, St Stephen's Green, Dub...                     NaN
# 12          [3 Fade St, Dublin, Dublin City, Ireland]                     NaN
# 13  [26 Lower Ormond Quay, Dublin, Dublin City, Ir...                     NaN
# 14     [5-9 Temple Bar, Dublin, Dublin City, Ireland]                     NaN
# 15     [111 Grafton St, Dublin, Dublin City, Ireland]                     NaN
# 16  [11 Wellington Quay, Dublin, Dublin City, Irel...                     NaN
# 17     [2 Exchequer St, Dublin, Dublin City, Ireland]                     NaN
# 18   [7-9 Exchequer St, Dublin, Dublin City, Ireland]                     NaN
# 19  [35 S Great Georges St, Dublin, Dublin City, I...                     NaN
# 20                     [Dublin, Dublin City, Ireland]                     NaN
# 21                      [1-4 Merrion St Lwr, Ireland]                     NaN
# 22      [50-53 Dame St, Dublin, Dublin City, Ireland]                     NaN
# 23                     [Dublin, Dublin City, Ireland]                     NaN
# 24  [The Merrion Hotel, Uppr Merrion St, Dublin, D...                     NaN
# 25     [46 Dame Street, Dublin, Dublin City, Ireland]                     NaN
# 26   [Meeting House Sq, Dublin, Dublin City, Ireland]                     NaN
# 27                    [5 Crow St., Δουβλίνο, Ireland]              Temple Bar
# 28      [12 Temple Bar, Dublin, Dublin City, Ireland]                     NaN
# 29       [4 Temple Ln S, Temple Bar, Dublín, Ireland]                     NaN
# 30  [6 Eustace St, Temple Bar, Dublin, Dublin City...                     NaN
# 31     [27 Eustace St., Dublin, Dublin City, Ireland]                     NaN
# 32  [48-49 Wellington Quay, Dublin, Dublin City, I...                     NaN
# 33                     [Dublin, Dublin City, Ireland]                     NaN
# 34  [The Clarence, 6-8 Wellington Quay, Dublin, Du...                     NaN
# 35      [12 E Essex St, Dublin, Dublin City, Ireland]                     NaN
# 36  [Customs House Dock (IFSC), Dublin, Dublin Cit...                     NaN
# 37        [20 Crane Ln, Dublin, Dublin City, Ireland]                     NaN
# 38  [2-5 Wellington Quay, Dublin, Dublin City, Ire...                     NaN
# 39  [Tara St DART Station, Dublin, Dublin City, Ir...                     NaN
# 40  [42-44 O'Connell St Lwr, Dublin, Dublin City, ...                     NaN
# 41  [6 Millennium Walkway, Dublin, Dublin City, Ir...                     NaN
# 42  [Odeon, Harcourt St, Dublin, Dublin City, Irel...                     NaN
# 43  [16-18 Fishamble St, Dublin, Dublin City, Irel...                     NaN
# 44  [Camden Court Hotel (Camden St), Dublin, Dubli...                     NaN
# 45  [1st Flor, Jervis Street Shopping Centre, Dubl...                     NaN
# 46  [The Mansion House, Dawson St, Dublin, Dublin ...                     NaN
# 47  [La Stampa Hotel, Dawson St, Dublin, Dublin Ci...                     NaN
# 48         [Sussex Tce, Dublin, Dublin City, Ireland]                     NaN
# 49  [Hilton Dublin, Charlemont Pl, Dublin, Dublin ...                     NaN
#
#    crossStreet                        id
# 0          NaN  4ade0eedf964a520767021e3
# 1          NaN  4ade0f35f964a5207d7121e3
# 2          NaN  4ade0f0bf964a520ea7021e3
# 3          NaN  5409de55498e23475796305c
# 4          NaN  4ade0efdf964a520ab7021e3
# 5          NaN  4ade0ef1f964a520847021e3
# 6          NaN  4b9adba1f964a520d2dc35e3
# 7          NaN  4ade0ef0f964a520817021e3
# 8          NaN  4ade0ef2f964a520877021e3
# 9          NaN  4ade0f09f964a520e17021e3
# 10         NaN  547b8b03498e3bbc4618dd6a
# 11         NaN  4c1421a27f7f2d7fc96ae068
# 12         NaN  4af7375cf964a5203c0722e3
# 13         NaN  4c167de296040f477ced72a5
# 14         NaN  4ade0f29f964a5204d7121e3
# 15         NaN  4ffe9011e4b021eb8b8ad6f6
# 16         NaN  4fef5afde4b0660372575a48
# 17         NaN  4ade0f0bf964a520e97021e3
# 18         NaN  4af814edf964a520e80a22e3
# 19         NaN  4af5f828f964a5209dff21e3
# 20         NaN  55073bab498ebefdee03e118
# 21         NaN  5638fee3cd104e8bcdf6eb34
# 22         NaN  4b71fd6ff964a520b7682de3
# 23         NaN  57116c4b498e0859ea3dae93
# 24         NaN  4b88135af964a520e7dd31e3
# 25         NaN  4ade0f07f964a520d67021e3
# 26         NaN  4b5b0e4ef964a5202ee128e3
# 27         NaN  5a6cc25d356b4950ef9a247b
# 28         NaN  52b1fc53498ef2068fb1ef7f
# 29         NaN  5daca02318e43d0007e521f3
# 30         NaN  4b9cdbcaf964a520147f36e3
# 31         NaN  4d64f43c601d88bfd5a8bebb
# 32         NaN  4cfbb0f2d8468cfaa3fff56b
# 33         NaN  50b6433ae4b0a4380b8f7d37
# 34         NaN  4ade0ef1f964a520857021e3
# 35         NaN  4b7be483f964a52072722fe3
# 36        IFSC  4ade0eeef964a520797021e3
# 37         NaN  4e0fe3fe7d8b4d5613cd8853
# 38         NaN  50b33907e4b0dabb595a65f8
# 39         NaN  4b31158bf964a520ceff24e3
# 40         NaN  4b013fd7f964a520eb4122e3
# 41         NaN  50bdf9d5e4b090d00b4ad81b
# 42         NaN  54557bff498eee46cdfe7ea3
# 43         NaN  557480c7498eedcbad681a09
# 44   Camden St  4d0b5faad823b1f7e2f9e85c
# 45         NaN  4f3f99cae4b0ae065538fe3d
# 46         NaN  4ade0f06f964a520d07021e3
# 47         NaN  566c88f5498e1bdb151fc2e9
# 48         NaN  4bf6c2705ec320a1a6b485d3
# 49         NaN  50ca02c6245f2d4aa8c2c910

# %%
dataframe_filtered1=pd.DataFrame(dataframe_filtered)

dublin1Bar_map = folium.Map(location=[latitude1, longitude1], zoom_start=13) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude1, longitude1],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(dublin1Bar_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['categories']):
    label = '{}, {}'.format(dataframe_filtered['id'], dataframe_filtered['distance'])
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(dublin1Bar_map) 

# display map
dublin1Bar_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 10. Searching for Bars in 22A Drumcondra Rd Upper, Drumcondra, Dublin

# %%
address1 = "22A Drumcondra Rd Upper, Drumcondra, Dublin"

geolocator = Nominatim(user_agent="dublin1_agent")
location = geolocator.geocode(address1)
latitude2 = location.latitude
longitude2= location.longitude
print(latitude2, longitude2)
# Out:
# 53.3751179 -6.2509327

# %%
url3 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude2, longitude2, VERSION, search_query, radius, LIMIT)
url3
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2ECMKGACQRNDAOTLP02N52AXE5A0AUCMK5RBWF5TWHSBLI41&client_secret=CGYL4DFESDX1MSNLQBTPV2WAFV4FABLQ5WZS2IODNVQ0LDAX&ll=53.3751179,-6.2509327&v=20180604&query=Bar&radius=1000&limit=1000'

# %%
result3 = requests.get(url3).json()
result3
# Out:
# {'meta': {'code': 200, 'requestId': '5f149f100dc37732398dcd51'},
#  'response': {'venues': [{'id': '4fa2db14e4b0887595de148e',
#     'name': 'The Apppian Bar at the Regency Hotel',
#     'location': {'lat': 53.37735453033255,
#      'lng': -6.246693776928476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.37735453033255,
#        'lng': -6.246693776928476}],
#      'distance': 375,
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186931',
#     'hasPerk': False},
#    {'id': '4e56d859a8099c9a1b24d6d7',
#     'name': 'The Bar',
#     'location': {'lat': 53.36781715696424,
#      'lng': -6.255753740921622,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.36781715696424,
#        'lng': -6.255753740921622}],
#      'distance': 873,
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186931',
#     'hasPerk': False},
#    {'id': '5c6ddf29178a2a002ca8087e',
#     'name': 'Delight Coffee Bar',
#     'location': {'address': '151 Drumcondra Road Lower',
#      'lat': 53.3674674,
#      'lng': -6.2552501,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.3674674,
#        'lng': -6.2552501}],
#      'distance': 898,
#      'postalCode': 'D09 YKH9',
#      'cc': 'IE',
#      'city': 'Cabra - Drumcondra',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['151 Drumcondra Road Lower',
#       'Cabra - Drumcondra',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186931',
#     'hasPerk': False},
#    {'id': '55a77ceb498e56620655e1ba',
#     'name': "Benny's Barbershop",
#     'location': {'lat': 53.371669,
#      'lng': -6.253018,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.371669,
#        'lng': -6.253018}],
#      'distance': 408,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '54541900498ea6ccd0202697',
#       'name': 'Health & Beauty Service',
#       'pluralName': 'Health & Beauty Services',
#       'shortName': 'Health & Beauty',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186931',
#     'hasPerk': False},
#    {'id': '51309b24e4b0ef4e03b3be5f',
#     'name': 'The Grafton Barber',
#     'location': {'address': '102 Uppr Drumcondra Rd',
#      'lat': 53.372099850151464,
#      'lng': -6.253101987427163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.372099850151464,
#        'lng': -6.253101987427163}],
#      'distance': 365,
#      'postalCode': '9',
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['102 Uppr Drumcondra Rd',
#       'Dublin',
#       'Dublin City',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186931',
#     'hasPerk': False},
#    {'id': '4d3183b88250f04d9c42eae0',
#     'name': "John's Barbers",
#     'location': {'lat': 53.38238304978673,
#      'lng': -6.2458819579276,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.38238304978673,
#        'lng': -6.2458819579276}],
#      'distance': 875,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186931',
#     'hasPerk': False},
#    {'id': '4dfca947b61c84188eed6c5c',
#     'name': "Pat's Barber Shop",
#     'location': {'lat': 53.380764,
#      'lng': -6.240358,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.380764,
#        'lng': -6.240358}],
#      'distance': 942,
#      'cc': 'IE',
#      'city': 'Dublin',
#      'state': 'Dublin City',
#      'country': 'Ireland',
#      'formattedAddress': ['Dublin', 'Dublin City', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595186931',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venue2Bar = result3['response']['venues']

# tranform venues into a dataframe
data2Bar = json_normalize(venue2Bar)
data2Bar.head()
# Out:
# /home/greyce/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                  name  \
# 0  4fa2db14e4b0887595de148e  The Apppian Bar at the Regency Hotel
# 1  4e56d859a8099c9a1b24d6d7                               The Bar
# 2  5c6ddf29178a2a002ca8087e                    Delight Coffee Bar
# 3  55a77ceb498e56620655e1ba                    Benny's Barbershop
# 4  51309b24e4b0ef4e03b3be5f                    The Grafton Barber
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1595186931    False
# 1  [{'id': '4bf58dd8d48988d1d5941735', 'name': 'H...  v-1595186931    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1595186931    False
# 3  [{'id': '54541900498ea6ccd0202697', 'name': 'H...  v-1595186931    False
# 4  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...  v-1595186931    False
#
#    location.lat  location.lng  \
# 0     53.377355     -6.246694
# 1     53.367817     -6.255754
# 2     53.367467     -6.255250
# 3     53.371669     -6.253018
# 4     53.372100     -6.253102
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 53.37735453033255...                375
# 1  [{'label': 'display', 'lat': 53.36781715696424...                873
# 2  [{'label': 'display', 'lat': 53.3674674, 'lng'...                898
# 3  [{'label': 'display', 'lat': 53.371669, 'lng':...                408
# 4  [{'label': 'display', 'lat': 53.37209985015146...                365
#
#   location.cc       location.city location.state location.country  \
# 0          IE              Dublin    Dublin City          Ireland
# 1          IE              Dublin    Dublin City          Ireland
# 2          IE  Cabra - Drumcondra    Dublin City          Ireland
# 3          IE                 NaN            NaN          Ireland
# 4          IE              Dublin    Dublin City          Ireland
#
#                            location.formattedAddress  \
# 0                     [Dublin, Dublin City, Ireland]
# 1                     [Dublin, Dublin City, Ireland]
# 2  [151 Drumcondra Road Lower, Cabra - Drumcondra...
# 3                                          [Ireland]
# 4  [102 Uppr Drumcondra Rd, Dublin, Dublin City, ...
#
#             location.address location.postalCode
# 0                        NaN                 NaN
# 1                        NaN                 NaN
# 2  151 Drumcondra Road Lower            D09 YKH9
# 3                        NaN                 NaN
# 4     102 Uppr Drumcondra Rd                   9

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in data2Bar.columns if col.startswith('location.')] + ['id']
dataframe_filtered = data2Bar.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name               categories        lat  \
# 0  The Apppian Bar at the Regency Hotel                      Bar  53.377355
# 1                               The Bar                Hotel Bar  53.367817
# 2                    Delight Coffee Bar              Coffee Shop  53.367467
# 3                    Benny's Barbershop  Health & Beauty Service  53.371669
# 4                    The Grafton Barber       Salon / Barbershop  53.372100
# 5                        John's Barbers       Salon / Barbershop  53.382383
# 6                     Pat's Barber Shop       Salon / Barbershop  53.380764
#
#         lng                                     labeledLatLngs  distance  cc  \
# 0 -6.246694  [{'label': 'display', 'lat': 53.37735453033255...       375  IE
# 1 -6.255754  [{'label': 'display', 'lat': 53.36781715696424...       873  IE
# 2 -6.255250  [{'label': 'display', 'lat': 53.3674674, 'lng'...       898  IE
# 3 -6.253018  [{'label': 'display', 'lat': 53.371669, 'lng':...       408  IE
# 4 -6.253102  [{'label': 'display', 'lat': 53.37209985015146...       365  IE
# 5 -6.245882  [{'label': 'display', 'lat': 53.38238304978673...       875  IE
# 6 -6.240358  [{'label': 'display', 'lat': 53.380764, 'lng':...       942  IE
#
#                  city        state  country  \
# 0              Dublin  Dublin City  Ireland
# 1              Dublin  Dublin City  Ireland
# 2  Cabra - Drumcondra  Dublin City  Ireland
# 3                 NaN          NaN  Ireland
# 4              Dublin  Dublin City  Ireland
# 5                 NaN          NaN  Ireland
# 6              Dublin  Dublin City  Ireland
#
#                                     formattedAddress  \
# 0                     [Dublin, Dublin City, Ireland]
# 1                     [Dublin, Dublin City, Ireland]
# 2  [151 Drumcondra Road Lower, Cabra - Drumcondra...
# 3                                          [Ireland]
# 4  [102 Uppr Drumcondra Rd, Dublin, Dublin City, ...
# 5                                          [Ireland]
# 6                     [Dublin, Dublin City, Ireland]
#
#                      address postalCode                        id
# 0                        NaN        NaN  4fa2db14e4b0887595de148e
# 1                        NaN        NaN  4e56d859a8099c9a1b24d6d7
# 2  151 Drumcondra Road Lower   D09 YKH9  5c6ddf29178a2a002ca8087e
# 3                        NaN        NaN  55a77ceb498e56620655e1ba
# 4     102 Uppr Drumcondra Rd          9  51309b24e4b0ef4e03b3be5f
# 5                        NaN        NaN  4d3183b88250f04d9c42eae0
# 6                        NaN        NaN  4dfca947b61c84188eed6c5c

# %%
dataframe_filtered2=pd.DataFrame(dataframe_filtered)

dublin2Bar_map = folium.Map(location=[latitude2, longitude2], zoom_start=13) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude2, longitude2],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(dublin2Bar_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['categories']):
    label = '{}, {}'.format(dataframe_filtered['id'], dataframe_filtered['distance'])
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(dublin2Bar_map) 

# display map
dublin2Bar_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Conclusion: According to the chart, the best address to open my bar is in the neighborhood of Drumcondra.
